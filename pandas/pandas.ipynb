# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df.head(10)  #max penggunaan head hanya (60)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
# 5          3  194611020DTF   NBA        1     1947  11/2/1946           1
# 6          4  194611020PRO   NBA        1     1947  11/2/1946           1
# 7          4  194611020PRO   NBA        0     1947  11/2/1946           1
# 8          5  194611020STB   NBA        1     1947  11/2/1946           1
# 9          5  194611020STB   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id       fran_id  ...  win_equiv  opp_id      opp_fran  \
# 0            0     TRH       Huskies  ...  40.294830     NYK        Knicks
# ...

# %%
df.tail(5) #sama seperti head max hanya (60)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.precision",2)
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
df["team_id"].value_counts(sort= False)
# Out:
# TRH      60
# NYK    5769
# CHS     260
# DTF      60
# WSC     291
#        ...
# NOK     164
# OKC     631
# BRK     271
# NOP     168
# CHO      82
# Name: team_id, Length: 104, dtype: int64

# %%
df.loc[df['fran_id' ]== 'Lakers','team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df['team_id']=='MNL','date_game'].agg((min,max))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
df.loc[df['team_id']=='BOS','date_game'].agg((min,max))
# Out:
# min    1/1/1948
# max    6/9/2012
# Name: date_game, dtype: object

# %%
revenues = pd.Series([555,777,999])
revenues
# Out:
# 0    555
# 1    777
# 2    999
# dtype: int64

# %%
city_revenues = pd.Series([555,777,999], index=['Jakarta','Tokyo','Bandung'])
city_revenues
# Out:
# Jakarta    555
# Tokyo      777
# Bandung    999
# dtype: int64

# %%
city_employee = pd.Series({

    'Lamongan':10,
    'Bandung':20,
    'Banjar':19
})

city_employee
# Out:
# Lamongan    10
# Bandung     20
# Banjar      19
# dtype: int64

# %%
city_employee.keys
# Out:
# <bound method Series.keys of Lamongan    10
# Bandung     20
# Banjar      19
# dtype: int64>

# %%
city_data = pd.DataFrame({
    'revenue': city_revenues,
    'employe': city_employee
})

city_data
# Out:
#           revenue  employe
# Bandung     999.0     20.0
# Banjar        NaN     19.0
# Jakarta     555.0      NaN
# Lamongan      NaN     10.0
# Tokyo       777.0      NaN

# %%
city_data.index
# Out:
# Index(['Bandung', 'Banjar', 'Jakarta', 'Lamongan', 'Tokyo'], dtype='object')

# %%
colors= pd.Series(
    ['red','yellow','ppurple'],
    index=[1,5,3]
)

colors
# Out:
# 1        red
# 5     yellow
# 3    ppurple
# dtype: object

# %%
print(colors[3])
print(colors.loc[1])
print(colors.iloc[1])
# Out:
# ppurple
# red
# yellow

# %%
print(colors.loc[1:3])
print(colors.iloc[1:3])
# Out:
# 1        red
# 5     yellow
# 3    ppurple
# dtype: object
# 5     yellow
# 3    ppurple
# dtype: object

# %%
toys = pd.DataFrame([
    {"name":"ball",
     "shape":"sphere"
     }
])

# %%
print(df.iloc[-2]) #iloc berdasarkan indexing
# Out:
# gameorder               63157
# game_id          201506170CLE
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           6/16/2015
# seasongame                102
# is_playoffs                 1
# team_id                   CLE
# fran_id             Cavaliers
# pts                        97
# elo_i                 1700.74
# elo_n                 1692.09
# win_equiv               59.29
# opp_id                    GSW
# opp_fran             Warriors
# opp_pts                   105
# opp_elo_i             1813.63
# opp_elo_n             1822.29
# game_location               H
# game_result                 L
# forecast                 0.48
# notes                     NaN
# Name: 126312, dtype: object

# %%
print(df.loc[df["gameorder"]==1])
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.72      41.71    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0    1306.72             H           L      0.64
# 1  Huskies       66     1300.0    1293.28             A           W      0.36
#
#   notes
# 0   NaN
# 1   NaN

# %%
df_decade=df[df['year_id']>2010]
df_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
df[df['notes'].notnull()].head()
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 930         466  194801300BLB   NBA        1     1948  1/30/1948          28
# 931         466  194801300BLB   NBA        0     1948  1/30/1948          31
# 1084        543  194803230CHS   NBA        1     1948  3/23/1948          49
# 1085        543  194803230CHS   NBA        0     1948  3/23/1948          49
# 1088        545  194803250CHS   NBA        1     1948  3/25/1948          49
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 930             0     WSC   Capitols   71  1469.35  1454.90      47.07    BLB
# 931             0     BLB  Baltimore   95  1434.05  1448.50      46.41    WSC
# 1084            1     WSC   Capitols   70  1465.90  1461.20      47.71    CHS
# 1085            1     CHS      Stags   74  1440.72  1445.42      46.09    WSC
# 1088            1     BLB  Baltimore   75  1477.26  1484.31      50.04    CHS
#
# ...

# %%
df[(df.fran_id.str.endswith('ers')) &(df.notes.notnull()) & (df.year_id >= 2000) & (df['_iscopy']==0)]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 95379       47690  200310300SEA   NBA        0     2004  10/30/2003
# 95384       47693  200310310LAC   NBA        0     2004  10/31/2003
# 110348      55175  200903130PHI   NBA        0     2009   3/13/2009
#
#         seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 95379            1            0     LAC  Clippers  100  1428.09  1421.46
# 95384            2            0     LAC  Clippers  105  1421.46  1411.31
# 110348          63            0     PHI    Sixers  104  1507.57  1510.89
#
#         win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 95379       32.56    SEA  Thunder      109    1523.13    1529.76
# 95384       31.54    SEA  Thunder      124    1529.76    1539.91
# 110348      41.89    CHI    Bulls      101    1482.24    1478.92
#
#        game_location game_result  forecast  \
# 95379              N           L      0.37
# ...

# %%
df[(df['team_id'].str.startswith('LA')) & (df.year_id)]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 9730         4866  196010190CIN   NBA        1     1961  10/19/1960
# 9739         4870  196010220STL   NBA        1     1961  10/22/1960
# 9744         4873  196010240LAL   NBA        0     1961  10/24/1960
# 9747         4874  196010250LAL   NBA        0     1961  10/25/1960
# 9756         4879  196010280GSW   NBA        1     1961  10/28/1960
# ...           ...           ...   ...      ...      ...         ...
# 126252      63127  201505080LAC   NBA        0     2015    5/8/2015
# 126260      63131  201505100LAC   NBA        0     2015   5/10/2015
# 126268      63135  201505120HOU   NBA        1     2015   5/12/2015
# 126276      63139  201505140LAC   NBA        0     2015   5/14/2015
# 126282      63142  201505170HOU   NBA        1     2015   5/17/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 9730             1            0     LAL    Lakers  123  1472.11  1456.23
# ...

# %%
poin = df.pts.sum()
poin
# Out:
# 12976235

# %%
df[(df.fran_id.str.endswith('ers')) &(df.notes.notnull()) & (df.year_id >= 2000) & (df['_iscopy']==0)].groupby(['year_id','game_result'])["game_id"].sum()
# Out:
# year_id  game_result
# 2004     L              200310300SEA200310310LAC
# 2009     W                          200903130PHI
# Name: game_id, dtype: object

# %%
df.groupby(['year_id','game_result'])["game_id"].count()
# Out:
# year_id  game_result
# 1947     L               350
#          W               350
# 1948     L               215
#          W               215
# 1949     L               380
#                         ...
# 2013     W              1314
# 2014     L              1319
#          W              1319
# 2015     L              1311
#          W              1311
# Name: game_id, Length: 138, dtype: int64

# %%
nba = df.copy()
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba['difference']= nba.pts - nba.opp_pts
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
renames=nba.rename(columns={"game_result":"result","game_location":"location"},inplace=True)
renames

# %%
elo_column = ['elo_i','elo_n','opp_elo_i',]
nba.drop(elo_column,inplace=True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\1. MSIB PYthon For Data Science\latihan-materi\pandas\pandas.ipynb Cell 35 in 2
#       <a href='vscode-notebook-cell:/d%3A/1.%20MSIB%20PYthon%20For%20Data%20Science/latihan-materi/pandas/pandas.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> elo_column = ['elo_i','elo_n','opp_elo_i',]
# ----> <a href='vscode-notebook-cell:/d%3A/1.%20MSIB%20PYthon%20For%20Data%20Science/latihan-materi/pandas/pandas.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a> nba.drop(elo_column,inplace=True,axis=1)
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
nba.location.value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: location, dtype: int64

# %%
nba.location = pd.Categorical(nba.location)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 21 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  opp_elo_n    126314 non-null  float64
#  16  location     126314 non-null  category
#  17  result       126314 non-null  object
# ...

# %%
non_null_note = nba.dropna(axis=1)

# %%
non_null_note
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba[(nba["pts"]>nba["opp_pts"]) & (nba["result"]!= 'W')].empty
# Out:
# True

# %%
nba[(nba["pts"]<nba["opp_pts"]) & (nba["result"]!= 'L')].empty
# Out:
# True

# %%
further_city_data = pd.DataFrame( {"revenue": [7000, 3400], "employe": [2, 2]}, index=["New York", "Barcelona"] )

# %%
further_city_data
# Out:
#            revenue  employe
# New York      7000        2
# Barcelona     3400        2

# %%
city_data
# Out:
#           revenue  employe
# Bandung     999.0     20.0
# Banjar        NaN     19.0
# Jakarta     555.0      NaN
# Lamongan      NaN     10.0
# Tokyo       777.0      NaN

# %%
all_city = pd.concat([city_data,further_city_data])
all_city
# Out:
#            revenue  employe
# Bandung      999.0     20.0
# Banjar         NaN     19.0
# Jakarta      555.0      NaN
# Lamongan       NaN     10.0
# Tokyo        777.0      NaN
# New York    7000.0      2.0
# Barcelona   3400.0      2.0

# %%
city_countries = pd.DataFrame({ "country": ["Holland", "Japan", "Holland", "Canada", "Spain"], "capital": [1, 1, 0, 0, 0]}, index=["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"] )

# %%
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
cities =pd.concat([all_city,city_countries],axis=1,join='inner')
cities
# Out:
#            revenue  employe country  capital
# Tokyo        777.0      NaN   Japan        1
# Barcelona   3400.0      2.0   Spain        0

# %%
countries = pd.DataFrame({ "population_millions": [17, 127, 37], "continent": ["Europe", "Asia", "North America"] }, index=["Holland", "Japan", "Canada"])

# %%
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# Japan                    127           Asia
# Canada                    37  North America

# %%
pd.merge(cities, countries, left_on="country", right_index=True)
# Out:
#        revenue  employe country  capital  population_millions continent
# Tokyo    777.0      NaN   Japan        1                  127      Asia

# %%
# %matplotlib inline 

nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum().plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\1. MSIB PYthon For Data Science\latihan-materi\pandas\pandas.ipynb Cell 53 in 3
#       <a href='vscode-notebook-cell:/d%3A/1.%20MSIB%20PYthon%20For%20Data%20Science/latihan-materi/pandas/pandas.ipynb#Y104sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_line_magic('matplotlib', 'inline')
# ----> <a href='vscode-notebook-cell:/d%3A/1.%20MSIB%20PYthon%20For%20Data%20Science/latihan-materi/pandas/pandas.ipynb#Y104sZmlsZQ%3D%3D?line=2'>3</a> nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum().plot(kind="scater")
#
# File c:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:933, in PlotAccessor.__call__(self, *args, **kwargs)
#     930     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     932 if kind not in self._all_kinds:
# ...
